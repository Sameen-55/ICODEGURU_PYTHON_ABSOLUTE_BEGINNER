# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameen-55/ICODEGURU_PYTHON_ABSOLUTE_BEGINNER/blob/main/ICODEGURU_DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Programming is a SET of code...
# #Compiler
# compiler is a program thats translate the higher langauge into machine langauge...
# Interpreter:
# Interpreter is a program thats translate the code line by line....
