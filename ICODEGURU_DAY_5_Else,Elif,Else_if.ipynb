# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameen-55/ICODEGURU_PYTHON_ABSOLUTE_BEGINNER/blob/main/ICODEGURU_DAY_5_Else%2CElif%2CElse_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("Enter any Number"))

if num1>5:
   print("Today is Rainy")
# Out:
# Enter any Number2

# %%
num1=int(input("Enter any Number"))
if num1>5:
   print("Today is Rainy")
else:
   print("Today is sunny")
# Out:
# Enter any Number11
# Today is Rainy

# %%
num1=int(input("Enter any Number"))
num2=int(input("Enter any Number"))

if num1>5:
  if num2<5:
   print("Today is Rainy")
elif num1==5:
  print("today is Hot")

else:
   print("Today is sunny")
# Out:
# Enter any Number1
# Enter any Number2
# Today is sunny
