# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameen-55/ICODEGURU_PYTHON_ABSOLUTE_BEGINNER/blob/main/ICODEGURU_DAY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello \n World")
# Out:
# Hello
#  World

# %%
print("Hello \t  World")
# Out:
# Hello 	  World

# %%
a = 5
b  =10
print(a+b)
print(type(a))
print(type(b))
# Out:
# 15
# <class 'int'>
# <class 'int'>

# %%
a = "sameen"
print(a)
print(type(a))
# Out:
# sameen
# <class 'str'>

# %%
a = "25"
b = int(a)

print(b)
print(type(b))

# %%
a = 10
b = 20
c = a+b
print(c)
# Out:
# 30

# %%
a = 10
b = 20
c = a*b*a*b
print(c)
# Out:
# 40000
